# %%
#when plotting graphs we hav e to import 2 libraries
#pandas which is used to read the files
#matplotlib which is used to plot various types of graphs

import pandas as pd
import matplotlib.pyplot as plt

# %%
#sample in this case is used to view/sample the specific number that has been called out from the data set in no particular order
#inthis case used to sample 10

#"air_quality_no2" in this case is our data set
#index collumn is the point of origin when plotting a graph
#parse dates is used to plot graphs

#shift tab to confirm
#Nan means not a number

kenya = pd.read_csv("air_quality_no2.csv", index_col = 0, parse_dates = True)

kenya.sample(10)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-06-01 10:00:00              NaN           33.3             9.0
# 2019-05-14 11:00:00              NaN           19.0            31.0
# 2019-06-04 12:00:00              NaN           23.3            32.0
# 2019-05-31 03:00:00              9.0           36.9            12.0
# 2019-06-13 17:00:00              NaN           28.8            11.0
# 2019-06-16 00:00:00              NaN           20.1            19.0
# 2019-06-15 10:00:00              NaN           17.6             8.0
# 2019-06-12 18:00:00              NaN           23.6            43.0
# 2019-05-17 21:00:00              NaN           24.7            36.0
# 2019-06-02 03:00:00              NaN           38.2            43.0

# %%
#the head function calls out the data set in order as seen below

kenya.head(10)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# 2019-05-07 07:00:00              NaN           72.4            26.0
# 2019-05-07 08:00:00              NaN           77.7            32.0
# 2019-05-07 09:00:00              NaN           67.9            32.0
# 2019-05-07 10:00:00              NaN           56.0            28.0
# 2019-05-07 11:00:00              NaN           34.5            21.0

# %%
#the describe function in grapgs is used to statistical analysis

kenya.describe()
# Out:
#        station_antwerp  station_paris  station_london
# count        95.000000    1004.000000      969.000000
# mean         25.778947      27.740538       24.777090
# std          12.682019      15.285746       11.214377
# min           7.500000       0.000000        0.000000
# 25%          16.750000      16.500000       19.000000
# 50%          23.000000      24.150000       25.000000
# 75%          34.500000      35.925000       31.000000
# max          74.500000      97.000000       97.000000

# %%
#plot is used to plot the graph
kenya.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
#tbis is how you select a specific row on a grapg

kenya["station_antwerp"].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
kenya["station_paris"].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
kenya["station_london"].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
#alpha is rersponsible for the tickness of the ink
#you put what you want to compare in the x and y axis

kenya.plot.scatter(x="station_paris",y="station_london",alpha=0.4)
# Out:
# <AxesSubplot:xlabel='station_paris', ylabel='station_london'>

# %%
kenya = pd.read_csv("air_quality_no2.csv", index_col = 0, parse_dates = True)

# %%
#figsize is responsible for the width and height of the graph
#width always comes first
#the 3 suplots 'subplots = true' is plotted after proving that yes there are subplots

axs = kenya.plot.area(figsize=(14,6), subplots = True)

# %%
#the first thing we did was to convert to cubic with a value of our own
#
kenya["londin_mg_per_cubic"] = kenya["station_london"] * 1.882

kenya["ratio_paris_antwerp"] = (kenya["station_antwerp"]/kenya["station_paris"])

# %%
#we use the remane function to change the name
#we call out kenya_rename to get the new names else kenya will just bring out the old data

kenya["londin_mg_per_cubic"] = kenya["station_london"] * 1.882

kenya["ratio_paris_antwerp"] = (kenya["station_antwerp"]/kenya["station_paris"])

kenya_rename = kenya.rename(

    columns={
        
        "station_antwerp":"Tanzania",
        "station_paris":"Uganda",
        "station_london":"Rwanda"
    }
)

kenya_rename
# Out:
#                      Tanzania  Uganda  Rwanda  londin_mg_per_cubic  \
# datetime
# 2019-05-07 02:00:00       NaN     NaN    23.0               43.286
# 2019-05-07 03:00:00      50.5    25.0    19.0               35.758
# 2019-05-07 04:00:00      45.0    27.7    19.0               35.758
# 2019-05-07 05:00:00       NaN    50.4    16.0               30.112
# 2019-05-07 06:00:00       NaN    61.9     NaN                  NaN
# ...                       ...     ...     ...                  ...
# 2019-06-20 22:00:00       NaN    21.4     NaN                  NaN
# 2019-06-20 23:00:00       NaN    24.9     NaN                  NaN
# 2019-06-21 00:00:00       NaN    26.5     NaN                  NaN
# 2019-06-21 01:00:00       NaN    21.8     NaN                  NaN
# 2019-06-21 02:00:00       NaN    20.0     NaN                  NaN
#
#                      ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                  NaN
# 2019-05-07 03:00:00             2.020000
# ...

# %%
#the old data as seen belowkenya
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      londin_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# ...
